# %%
import requests
import json
import pandas as pd

#https://blog.csdn.net/qq_43762932/article/details/131307467
#https://www.douyin.com/user/MS4wLjABAAAAfJbYiohY4syKtJ5pCwbCV-KgSFQCnPMUiyRRWjBrdEo
browse_header = {
    "Accept": "application/json, text/plain, */*",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.60 Safari/537.36",
    "Host": "www.douyin.com",
    "Referer": "https://www.douyin.com/discover",
    "Cookie": "_xsrf=Pd0NpG6J8kZdHtzBVnNyQP1g0rO7NKeg; _zap=d7f27b9f-4fe3-4ef4-9376-df278af16940;"
}

url = "https://www.douyin.com/aweme/v1/web/hot/search/list/?device_platform=webapp&aid=6383&channel=channel_pc_web"

res = requests.get(url, headers=browse_header).json()
# 实时上升热点
json.dumps(res)
# print("=======",json.dumps(res))
print(res)
content_list = res['data']['word_list']
title_list = []
order_list = []
score_list = []
desc_list = []
url_list = []
index = 0
for content in content_list:
    index += 1
    order_list.append(content['position'])
    title_list.append(content['word'])
    score_list.append(content['hot_value'])
    desc_list.append(content['word'])
    url_list.append(f"https://www.douyin.com/hot/{content['sentence_id']}")

df = pd.DataFrame({
    '热搜标题': title_list,
    '热搜排名': order_list,
    '热搜热度': score_list,
    '描述': desc_list,
    '链接地址': url_list
})
df.to_excel('抖音热搜榜001.xlsx', index=False)  # 保存结果数据
# Out:
# {'ad_search_list': None, 'board_tabs': None, 'data': {'active_time': '2024-04-28 20:10:21', 'recommend_list': None, 'share_info': {'share_link_desc': '我在看抖音热榜，发现最火的内容，赶快来看！戳这里>>', 'share_title': '我在看抖音热榜，发现最火的内容，赶快来看！', 'share_url': 'https://www.iesdouyin.com/share/billboard/?id=0'}, 'trending_desc': '实时上升热点', 'trending_list': [{'article_detail_count': 0, 'aweme_infos': None, 'discuss_video_count': 1, 'display_style': 0, 'drift_info': None, 'event_time': 1714272673, 'group_id': '6660359052435920136', 'hot_value': 0, 'hotlist_param': '{"version":1}', 'label': 0, 'related_words': None, 'sentence_id': '1673930', 'sentence_tag': 7000, 'video_count': 17, 'word': '成都全面取消限购', 'word_cover': {'uri': 'tos-cn-p-0015/ogMAjOnyeQxoLutF99peABnAwTGEINDbgmbLCD', 'url_list': ['https://p11-sign.douyinpic.com/tos-cn-p-0015/ogMAjOnyeQxoLutF99peABnAwTGEINDbgmbLCD~noop.jpeg?lk3s=bfd515bb&x-expires=1714327200&x-signature=Yyvw%2F1Su%2BwFeXLprlFffOtfU6tI%3D&from=3218412987', 'https://p3-sign.douyinpic.com/tos-cn-p-0015/ogMAjOnyeQxoLutF99peABnAwTGEINDbgmbLCD~noop.jpeg?lk3s=bfd515bb&x-expires=1714327200&x-signature=k5ZAdpk6VqauDg%2BwbkZV9Cwo0rk%3D&from=3218412987', 'https://p26-sign.douyinpic.com/tos-cn-p-0015/ogMAjOnyeQxoLutF99peABnAwTGEINDbgmbLCD~noop.jpeg?lk3s=bfd515bb&x-expires=1714327200&x-signature=INXUzHVSRpEOiPmZcvfAigsg3RE%3D&from=3218412987']}, 'word_sub_board': None, 'word_type': 3}, {'article_detail_count': 0, 'aweme_infos': None, 'discuss_video_count': 1, 'display_style': 0, 'drift_info': None, 'event_time': 1714213884, 'group_id': '7359887275558704420', 'hot_value': 0, 'hotlist_param': '{"version":1}', 'label': 8, 'related_words': None, 'sentence_id': '1673416', 'sentence_tag': 2012, 'video_count': 1, 'word': 'TXT连上中国的网了', 'word_cover': {'uri': 'tos-cn-p-0015/oI8yyQkmLAjTAkzFDHxMi9MBDezbgevKAsUggn', 'url_list': ['https://p26-sign.douyinpic.com/tos-cn-p-0015/oI8yyQkmLAjTAkzFDHxMi9MBDezbgevKAsUggn~noop.jpeg?lk3s=bfd515bb&x-expires=1714327200&x-signature=JcKHmBVws2ctazt%2BvkDwVmKIegc%3D&from=3218412987', 'https://p3-sign.douyinpic.com/tos-cn-p-0015/oI8yyQkmLAjTAkzFDHxMi9MBDezbgevKAsUggn~noop.jpeg?lk3s=bfd515bb&x-expires=1714327200&x-signature=HClBSir9Cev5e6h5IY%2BxoTlLK4Q%3D&from=3218412987', 'https://p6-sign.douyinpic.com/tos-cn-p-0015/oI8yyQkmLAjTAkzFDHxMi9MBDezbgevKAsUggn~noop.jpeg?lk3s=bfd515bb&x-expires=1714327200&x-signature=VOnMH3DmPVSZbolj%2Fvu8yRjHKYw%3D&from=3218412987']}, 'word_sub_board': None, 'word_type': 3}, {'aweme_infos': None, 'discuss_video_count': 1, 'display_style': 0, 'drift_info': None, 'event_time': 1714295764, 'group_id': '7357697879426127143', 'hot_value': 0, 'hotlist_param': '{"version":1}', 'label': 0, 'related_words': None, 'sentence_id': '1674325', 'sentence_tag': 2002, 'video_count': 3, 'word': '春色寄情人德华带娃', 'word_cover': {'uri': 'tos-cn-p-0015/oU8vzAIJLFzBgzAiIJsABTQt1CfZeFqhDuPlNM', 'url_list': ['https://p3-sign.douyinpic.com/tos-cn-p-0015/oU8vzAIJLFzBgzAiIJsABTQt1CfZeFqhDuPlNM~noop.jpeg?lk3s=bfd515bb&x-expires=1714327200&x-signature=ODXJJhO3nZFeylsQSzI0ie1XDug%3D&from=3218412987', 'https://p26-sign.douyinpic.com/tos-cn-p-0015/oU8vzAIJLFzBgzAiIJsABTQt1CfZeFqhDuPlNM~noop.jpeg?lk3s=bfd515bb&x-expires=1714327200&x-signature=y%2FaPLC5be%2FU14tKAMOKk%2BFgiO68%3D&from=3218412987', 'https://p11-sign.douyinpic.com/tos-cn-p-0015/oU8vzAIJLFzBgzAiIJsABTQt1CfZeFqhDuPlNM~noop.jpeg?lk3s=bfd515bb&x-expires=1714327200&x-signature=gDD6DQb3vG5vPgWq23mcDPFQKO0%3D&from=3218412987']}, 'word_sub_board': None, 'word_type': 3}, {'article_detail_count': 0, 'aweme_infos': None, 'discuss_video_count': 1, 'display_style': 0, 'drift_info': None, 'event_time': 1714272481, 'group_id': '7361306744985818395', 'hot_value': 0, 'hotlist_param': '{"version":1}', 'label': 0, 'related_words': None, 'sentence_id': '1673925', 'sentence_tag': 20001, 'video_count': 38, 'word': '广州为何会出现强龙卷和冰雹', 'word_cover': {'uri': 'tos-cn-p-0015/ocTERbxDaAQ1LWUmAVGQ9W4edbZelKACAnGBgG', 'url_list': ['https://p11-sign.douyinpic.com/tos-cn-p-0015/ocTERbxDaAQ1LWUmAVGQ9W4edb ...
