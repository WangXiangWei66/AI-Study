# %% [markdown]
# # 决策树

# %% [markdown]
# ## 【关键词】树，信息增益

# %% [markdown]
# ### 决策树的优缺点

# %% [markdown]
# 优点：计算复杂度不高，输出结果易于理解，对中间值的缺失不敏感，可以处理不相关特征数据。既能用于分类，也能用于回归
#
# 缺点：可能会产生过度匹配问题

# %% [markdown]
# ## 一、决策树的原理

# %% [markdown]
# ### predict()

# %% [markdown]
# 【二十个问题的游戏】
#
# 游戏的规则很简单：参与游戏的一方在脑海里想某个事物，其他参与者向他提问题，只允许提20个问题，问题的答案也只能用对或错回答。问问题的人通过推断分解，逐步缩小待猜测事物的范围。决策树的工作原理与20个问题类似，用户输人一系列数据 ，然后给出游戏的答案。

# %% [markdown]
# 我们经常使用决策树处理分类问题。近来的调查表明决策树也是最经常使用的数据挖掘算法。它之所以如此流行，一个很重要的原因就是使用者基本上不用了解机器学习算法，也不用深究它是如何工作的。

# %% [markdown]
# 如果以前没有接触过决策树，完全不用担心，它的概念非常简单。即使不知道它也可以通过简单的图形了解其工作原理。
#
# 决策树分类的思想类似于找对象。现想象一个女孩的母亲要给这个女孩介绍男朋友，于是有了下面的对话：
#
#       女儿：多大年纪了？
#
#       母亲：26。
#
#       女儿：长的帅不帅？
#
#       母亲：挺帅的。
#
#       女儿：收入高不？
#
#       母亲：不算很高，中等情况。
#
#       女儿：是公务员不？
#
#       母亲：是，在税务局上班呢。
#
#       女儿：那好，我去见见。
#
# 这个女孩的决策过程就是典型的分类树决策。相当于通过年龄、长相、收入和是否公务员对将男人分为两个类别：见和不见。假设这个女孩对男人的要求是：30岁以下、长相中等以上并且是高收入者或中等以上收入的公务员，那么这个可以用下图表示女孩的决策逻辑:
#
# ![1.PNG](attachment:1.PNG)

# %% [markdown]
# 上图完整表达了这个女孩决定是否见一个约会对象的策略，其中绿色节点表示判断条件，橙色节点表示决策结果，箭头表示在一个判断条件在不同情况下的决策路径，图中红色箭头表示了上面例子中女孩的决策过程。
#
# 这幅图基本可以算是一颗决策树，说它“基本可以算”是因为图中的判定条件没有量化，如收入高中低等等，还不能算是严格意义上的决策树，如果将所有条件量化，则就变成真正的决策树了。
#
# 有了上面直观的认识，我们可以正式定义决策树了：
#
# 决策树（decision tree）是一个树结构（可以是二叉树或非二叉树）。其每个非叶节点表示一个特征属性上的测试，每个分支代表这个特征属性在某个值域上的输出，而每个叶节点存放一个类别。使用决策树进行决策的过程就是从根节点开始，测试待分类项中相应的特征属性，并按照其值选择输出分支，直到到达叶子节点，将叶子节点存放的类别作为决策结果。
#
# 可以看到，决策树的决策过程非常直观，容易被人理解。目前决策树已经成功运用于医学、制造产业、天文学、分支生物学以及商业等诸多领域。

# %% [markdown]
# 之前介绍的K-近邻算法可以完成很多分类任务，但是它最大的缺点就是无法给出数据的内在含义，决策树的主要优势就在于数据形式非常容易理解。

# %% [markdown]
# 决策树算法能够读取数据集合，构建类似于上面的决策树。决策树很多任务都是为了数据中所蕴含的知识信息，因此决策树可以使用不熟悉的数据集合，并从中提取出一系列规则，机器学习算法最终将使用这些机器从数据集中创造的规则。专家系统中经常使用决策树，而且决策树给出结果往往可以匹敌在当前领域具有几十年工作经验的人类专家。

# %% [markdown]
# 知道了决策树的定义以及其应用方法，下面介绍决策树的构造算法。

# %%
# 构建决策树需要解决的两个问题: 
# 1. 优先选择哪个特征进行分裂, 原则上是越快构建决策树越好. ID3, C4.5, CART
# 2. 分裂特征的时候, 如何选择分裂的标准. 一个原则: 希望分裂的子节点, 越纯(pure)越好.

# %% [markdown]
# ## 二、决策树的构造

# %% [markdown]
# #### 分类解决离散问题，回归解决连续问题

# %% [markdown]
# - 决策树：信息论
# - 逻辑斯底回归、贝叶斯：概率论

# %% [markdown]
# 不同于逻辑斯蒂回归和贝叶斯算法，决策树的构造过程不依赖领域知识，它使用属性选择度量来选择将元组最好地划分成不同的类的属性。所谓决策树的构造就是进行属性选择度量确定各个特征属性之间的拓扑结构。
#
# 构造决策树的关键步骤是分裂属性。所谓分裂属性就是在某个节点处按照某一特征属性的不同划分构造不同的分支，其目标是让各个分裂子集尽可能地“纯”。尽可能“纯”就是尽量让一个分裂子集中待分类项属于同一类别。分裂属性分为三种不同的情况：
#
#       1、属性是离散值且不要求生成二叉决策树。此时用属性的每一个划分作为一个分支。
#
#       2、属性是离散值且要求生成二叉决策树。此时使用属性划分的一个子集进行测试，按照“属于此子集”和“不属于此子集”分成两个分支。
#
#       3、属性是连续值。此时确定一个值作为分裂点split_point，按照>split_point和<=split_point生成两个分支。
#
# 构造决策树的关键性内容是进行属性选择度量，属性选择度量是一种选择分裂准则，它决定了拓扑结构及分裂点split_point的选择。
#
# 属性选择度量算法有很多，一般使用自顶向下递归分治法，并采用不回溯的贪心策略。这里介绍常用的ID3算法。

# %% [markdown]
# #### ID3算法

# %% [markdown]
# 划分数据集的大原则是：*将无序的数据变得更加有序。*
#
# 我们可以使用多种方法划分数据集，但是每种方法都有各自的优缺点。组织杂乱无章数据的一种方法就是使用信息论度量信息，信息论是量化处理信息的分支科学。我们可以在划分数据之前使用信息论量化度量信息的内容。
#
# 在划分数据集之前之后信息发生的变化称为信息增益，知道如何计算信息增益，我们就可以计算每个特征值划分数据集获得的信息增益，获得信息增益最高的特征就是最好的选择。
#
# 在可以评测哪种数据划分方式是最好的数据划分之前，我们必须学习如何计算信息增益。集合信息的度量方式称为香农熵或者简称为熵，这个名字来源于信息论之父克劳德•香农。
#
# entropy
#
# 熵定义为信息的期望值，在明晰这个概念之前，我们必须知道信息的定义。如果待分类的事务可能划分在多个分类之中，则符号x的信息定义为：
#
# ![2.PNG](attachment:2.PNG)
#
# 其中p(x)是选择该分类的概率
#
# 为了计算熵，我们需要计算所有类别所有可能值包含的信息期望值，通过下面的公式得到：
#
# ![3.PNG](attachment:3.PNG)
#
# 其中n是分类的数目。
#
# 在决策树当中，设D为用类别对训练元组进行的划分，则D的熵（entropy）表示为：
#
# ![4.gif](attachment:4.gif)
#
# 其中pi表示第i个类别在整个训练元组中出现的概率，可以用属于此类别元素的数量除以训练元组元素总数量作为估计。熵的实际意义表示是D中元组的类标号所需要的平均信息量。
#
# 现在我们假设将训练元组D按属性A进行划分，则A对D划分的期望信息为：
#
# ![5.gif](attachment:5.gif)
#
# 而信息增益即为两者的差值：
#
# ![6.gif](attachment:6.gif)
#
# ID3算法就是在每次需要分裂时，计算每个属性的增益率，然后选择增益率最大的属性进行分裂。下面我们继续用SNS社区中不真实账号检测的例子说明如何使用ID3算法构造决策树。为了简单起见，我们假设训练集合包含10个元素：
#
# ![7.png](attachment:7.png)
#
# 其中s、m和l分别表示小、中和大。
#
# 设L、F和H表示日志密度、好友密度、是否使用真实头像，下面计算各属性的信息增益。
#
# ![8.gif](attachment:8.gif)
# ![9.gif](attachment:9.gif)
# ![10.gif](attachment:10.gif)
#
# 因此日志密度的信息增益是0.276。
#
# 用同样方法得到F和H的信息增益分别为0.553和0.033。
#
# 因为F具有最大的信息增益，所以第一次分裂选择F为分裂属性，分裂后的结果如下图表示：
#
# ![11.png](attachment:11.png)
#
# 在上图的基础上，再递归使用这个方法计算子节点的分裂属性，最终就可以得到整个决策树。

# %% [markdown]
# ### 练习
# 计算上图的信息熵，确定下一个分类的特征

# %%
import numpy as np

# %%
np.log(0.5)
# Out:
# -0.6931471805599453

# %%
# 通过计算不同特征的信息增益, 来判断优先使用哪个特征进行分裂. 
# 先计算账号是否真实本身的信息熵. 
#  2种情况, yes和no, 
# 3个no, 7个yes
info_D = -0.3 * np.log2(0.3) + (-0.7) * np.log2(0.7)
info_D
# Out:
# 0.8812908992306927

# %%
# 不要对信息熵有误区: 误认为信息熵是概率, 是0到1之间的, 信息熵不是概率, 虽然是大于0的, 但是可以大于1.

# %%
np.log2(1)
# Out:
# 0.0

# %%
# 使用日志密度对账号是否真实进行划分的信息熵. 
# s 0.3, l 0.3, m 0.4,
# s中, 2个是no, 一个是yes
# l中, 3个全是yes
# m中, 3个yes, 一个no
info_L = 0.3 * (-(1/3) * np.log2(1/3) + (-2/3) * np.log2(2/3)) + 0.3 * (-1 * np.log2(1)) + 0.4 * ((-1/4) * np.log2(1/4) + (-3/4) * np.log2(3/4))
info_L
# Out:
# 0.6

# %%
# 使用日志密度对账号是否真实进行划分的信息增益.
gain_L = info_D - info_L
gain_L
# Out:
# 0.2812908992306927

# %%
# 好友密度和是否使用真实头像的信息增益的计算, 交给大家课后去算. 
# 星期一告诉我, 应该优先选择哪个特征来分裂

# %%
# 通过计算法先使用好友密度对账号是否真实进行划分的信息增益最大, 所以优先选择好友密度对账号是否真实进行划分.

# %%
# ID3的优缺点:
# 优点: 简单, 好理解. 
# 缺点: 1. 存在大量的对数运算. 对计算机不友好. 2. 容易优先对比较离散的特征进行划分, 可能会导致分类错误.

# %%
# 假如加入了新的一列叫做ID, 即每一行一个数字编号. 
info_ID = -0.1 * np.log2(0.1) * 10
info_ID
# Out:
# 3.3219280948873626

# %%
0.1 * (-1* np.log2(1)) * 10
# Out:
# -0.0

# %%
gain_ID = info_D - 0
gain_ID
# Out:
# 0.8812908992306927

# %%
# 可以让信息增益除上特征本身的信息熵, 人为的降低离散特征的信息增益.信息增益率. 这种算法叫做C4.5算法. 
# C4.5算法是对ID3的改进.

# %%
gain_ID / info_ID
# Out:
# 0.2652949955741215

# %%
# 日志密度本身的信息熵
info_L = -0.3 * np.log2(0.3) - 0.4  * np.log2(0.4) - 0.3 * np.log2(0.3)
info_L
# Out:
# 1.5709505944546684

# %%
# 日志密度的信息增益率
gain_L / info_L
# Out:
# 0.17905776300262236

# %%
#好友密度，4个s，1个yes，3个no
#2个l，都是yes
#4个m都是yes
info_F = 0.4 * (-(1/4) * np.log2(1/4) + (-3/4) * np.log2(3/4)) + 0.2 * (-1 * np.log2(1)) + 0.4 * (-1 * np.log2(1))
info_F
# Out:
# 0.32451124978365314

# %%
info_D = -0.3 * np.log2(0.3) + (-0.7) * np.log2(0.7)
gain_F = info_D -info_F
gain_F
# Out:
# 0.5567796494470396

# %%
# 计算好友密度的信息增益率
info_F = -0.4 * np.log2(0.4) - 0.2 * np.log2(0.2) - 0.4 * np.log2(0.4)
info_F
# Out:
# 1.5219280948873621

# %%
gain_F / info_F
# Out:
# 0.36583834106055246

# %%
# CART 算法: classification and regression tree 分类和回归树. 
# ID3和C4.5只能做分类任务. CART既可以做分类, 也可以做回归. 
# CART树是二叉树. 
# CART算法通过计算基尼不纯度: gini impurity
# 思想上跟计算信息增益很像, CART把计算信息熵换成了计算基尼系数.

# %% [markdown]
# $$gini = 1 - \sum p(x)^2$$

# %%
# 计算账号是否真实本身的基尼系数
# 3个no, 7个yes
gini_D = 1 - (0.3 ** 2 + 0.7 ** 2)
gini_D
# Out:
# 0.42000000000000004

# %%
# 使用日志面对对账号是否真实进行划分的基尼系数
# s 0.3, l 0.3, m 0.4,
# s中, 2个是no, 一个是yes
# l中, 3个全是yes
# m中, 3个yes, 一个no
gini_L = 0.3 * (1 - ((1/3) ** 2 + (2/3) ** 2)) + 0.4 * (1 - ((1/4) ** 2 +(3/4)**2)) + 0.3 * (1 - 1 ** 2)
gini_L
# Out:
# 0.2833333333333333

# %%
# 使用日志密度对账号是否真实进行划分的基尼不纯度
gini_D - gini_L
# Out:
# 0.13666666666666671

# %%
#好友密度，4个s，1个yes，3个no
#2个l，都是yes
#4个m都是yes
gini_F = 0.4 * (1 - ((1/4) ** 2 + (3/4) ** 2)) 
gini_F
# Out:
# 0.15000000000000002

# %%
# 使用好友密度对账号是否真实进行划分的基尼不纯度
gini_D - gini_F
# Out:
# 0.27

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DecisionTreeClassifier()

# %% [markdown]
# ## 三、实战

# %% [markdown]
# 【注意】
# 参数max_depth越大，越容易过拟合

# %% [markdown]
# ### 1、使用自带的iris数据集

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()
data = iris.data
target = iris.target

# %% [markdown]
# 使用决策树算法

# %%
DecisionTreeClassifier().fit(data, target).score(data, target)
# Out:
# 1.0

# %%
# 决策树的优缺点:
# 1. 优点: 1. 对异常值不敏感. 准确率还不错, 可以分类也可以做回归. 
# 2. 缺点: 容易过拟合.

# %%
# 一般使用决策树需要对决策树进行剪枝操作. 
# 所谓剪枝操作就是在构建决策树之前, 提前对决策树设置一些参数, 比如树的最大深度, max_depth
# min_samples_split 最小分割样本数
# min_samples_leaf 最小叶子节点样本数. 
# 上面这个两个参数一般都是样本量比较大的时候有效果.

# %%
DecisionTreeClassifier(max_depth=2).fit(data, target).score(data, target)
# Out:
# 0.96

# %%
DecisionTreeClassifier(min_samples_split=8, min_samples_leaf=4).fit(data, target).score(data, target)
# Out:
# 0.9733333333333334

# %% [markdown]
# 使用KNN算法

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
KNeighborsClassifier().fit(data, target).score(data, target)
# Out:
# 0.9666666666666667

# %% [markdown]
# 使用逻辑斯蒂回归算法

# %%
from sklearn.linear_model import LogisticRegression

# %%
LogisticRegression(max_iter=10000).fit(data, target).score(data, target)
# Out:
# 0.9733333333333334

# %% [markdown]
# ### 2、使用回归预测一个圆

# %% [markdown]
# 使用RandomState生成固定随机数
# 创建-100到100之间的角度
# 生成正弦值和余弦值
# 添加噪声

# %% [markdown]
# 创建不同深度的决策树
# 进行数据训练

# %%
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# 创建-100到100的预测数据，间隔为0.01
# 对数据进行预测

# %%
# 圆的参数方程
# a + rcosθ = x
# b + rsinθ = y
# (x - a) ^2 + (y - b)^2 = r^2 一般方程

# %%
# 圆心在原点, 半径是1
arc = np.linspace(-100, 100, 100)

# %%
x = np.cos(arc)
y = np.sin(arc)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x, y)
plt.axis('equal')
# Out:
# (-1.095150864381248,
#  1.0959147801216806,
#  -1.0955427033251968,
#  1.095542703325194)

# %%
# 加上一点噪声
x[::4] += np.random.randn(25) * 0.5
y[::4] += np.random.randn(25) * 0.5
plt.scatter(x, y)
plt.axis('equal')
# Out:
# (-1.3564402447056694,
#  1.2281082516482704,
#  -1.7750791359802103,
#  1.9317010319048018)

# %% [markdown]
# 显示图片

# %%
#  根据弧度去预测圆上的点的坐标
target = np.c_[x, y]
target
# Out:
# array([[ 0.07292075,  0.58770887],
#        [-0.83070375,  0.55671472],
#        [-0.14055309, -0.99007314],
#        [ 0.95282479,  0.30352086],
#        [-0.32481771,  0.5089489 ],
#        [-0.35564049, -0.93462283],
#        [ 0.99632089,  0.08570117],
#        [-0.5100235 ,  0.86016046],
#        [-0.98552687, -1.31524721],
#        [ 0.99066117, -0.13634679],
#        [-0.30756495,  0.95152709],
#        [-0.7234301 , -0.69039764],
#        [ 1.11062877,  0.53939771],
#        [-0.08993195,  0.99594791],
#        [-0.85798654, -0.51367217],
#        [ 0.83540268, -0.54963839],
#        [ 0.3061399 ,  1.76321102],
#        [-0.95021222, -0.31160349],
#        [ 0.69346395, -0.72049132],
#        [ 0.3476887 ,  0.93761003],
#        [-1.23896077, -0.07536614],
#        [ 0.51731156, -0.85579714],
#        [ 0.54608532,  0.83772956],
#        [-0.9917836 ,  0.1279269 ],
#        [ 0.3165376 , -1.60658913],
#        [ 0.71753955,  0.69651776],
#        [-0.93907827,  0.34370335],
# ...

# %%
tree = DecisionTreeRegressor(max_depth=50)
tree.fit(arc.reshape(-1, 1), target)
# Out:
# DecisionTreeRegressor(max_depth=50)

# %%
X_test = np.linspace(-100, 100, 20000).reshape(-1, 1)
y_ = tree.predict(X_test)

# %%
y_
# Out:
# array([[ 0.07292075,  0.58770887],
#        [ 0.07292075,  0.58770887],
#        [ 0.07292075,  0.58770887],
#        ...,
#        [ 0.86231887, -0.50636564],
#        [ 0.86231887, -0.50636564],
#        [ 0.86231887, -0.50636564]])

# %%
plt.scatter(y_[:, 0], y_[:, 1])
plt.axis('equal')
# Out:
# (-1.3357219956351545,
#  1.1073705482766287,
#  -1.658595220021282,
#  1.323777740972906)

# %% [markdown]
# ### 随机森林

# %%
# random forest 
# 随机森林就是在决策树的基础上发展出来一个集成算法. 
# 集成算法:
1. bagging: 套袋法, 代表算法: 随机森林
2. boosting: 提升法, 代表算法: GBDT,XGBoost
3. stacking: 堆叠法, 没有代表算法.

# %%
# 随机森林中随机的含义:
1. 随机样本: 生成森林中的树的样本是随机, 但是要求生成每棵树的样本数是相同. 
2. 随机特征: 生成每棵树的特征是随机的, 要求每棵树的特征数是相同的.

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
iris = load_iris()
data = iris.data
target = iris.target

# %%
# n_estimators=100 森林中树的个数, 默认是100. 
RandomForestClassifier(max_depth=2).fit(data, target).score(data, target)
# Out:
# 0.9733333333333334

# %%
# 随机森林做分类, 进行投票. 
# 随机森林做回归, 计算均值.

# %% [markdown]
# ## 四、作业

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1、预测隐形眼镜的类型

# %% [markdown]
# 分析lenses.txt文件

# %%
lenses = pd.read_csv('../../data/lenses.txt',sep = '\t',header = None)
lenses
# Out:
#              0      1    2        3          4
# 0        young  myope   no  reduced  no lenses
# 1        young  myope   no   normal       soft
# 2        young  myope  yes  reduced  no lenses
# 3        young  myope  yes   normal       hard
# 4        young  hyper   no  reduced  no lenses
# 5        young  hyper   no   normal       soft
# 6        young  hyper  yes  reduced  no lenses
# 7        young  hyper  yes   normal       hard
# 8          pre  myope   no  reduced  no lenses
# 9          pre  myope   no   normal       soft
# 10         pre  myope  yes  reduced  no lenses
# 11         pre  myope  yes   normal       hard
# 12         pre  hyper   no  reduced  no lenses
# 13         pre  hyper   no   normal       soft
# 14         pre  hyper  yes  reduced  no lenses
# 15         pre  hyper  yes   normal  no lenses
# 16  presbyopic  myope   no  reduced  no lenses
# 17  presbyopic  myope   no   normal  no lenses
# 18  presbyopic  myope  yes  reduced  no lenses
# ...

# %%
#将类别型数据转化为字符串标签
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()
columns = lenses.columns[0:4]
for col in columns:
    lenses[col] = encoder.fit_transform(lenses[col])

# %%
lenses
# Out:
#     0  1  2  3          4
# 0   2  1  0  1  no lenses
# 1   2  1  0  0       soft
# 2   2  1  1  1  no lenses
# 3   2  1  1  0       hard
# 4   2  0  0  1  no lenses
# 5   2  0  0  0       soft
# 6   2  0  1  1  no lenses
# 7   2  0  1  0       hard
# 8   0  1  0  1  no lenses
# 9   0  1  0  0       soft
# 10  0  1  1  1  no lenses
# 11  0  1  1  0       hard
# 12  0  0  0  1  no lenses
# 13  0  0  0  0       soft
# 14  0  0  1  1  no lenses
# 15  0  0  1  0  no lenses
# 16  1  1  0  1  no lenses
# 17  1  1  0  0  no lenses
# 18  1  1  1  1  no lenses
# 19  1  1  1  0       hard
# 20  1  0  0  1  no lenses
# 21  1  0  0  0       soft
# 22  1  0  1  1  no lenses
# 23  1  0  1  0  no lenses

# %%
data = lenses.iloc[:,:-1]  #拿到除最后一列外的所有数据
target = lenses.iloc[:,-1]#拿到最后一列数据

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(data,target,test_size=5,random_state=9)

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train,y_train)
dt.score(X_test,y_test)
# Out:
# 0.6

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
rf.score(X_test,y_test)
# Out:
# 0.6

# %% [markdown]
# #### 2、使用make_blobs产生数据，训练模型，并画出类别边界。注意观察不同max_depth的分类边界线的效果.
# 随便再观察一下随机森林的分类边界线.

# %% [markdown]
# ### DecisionTreeClassifier

# %% [markdown]
# #### 三分类

# %%
from sklearn.datasets import make_blobs
data,target = make_blobs(centers=3,random_state=0) #使用了三个数据中心，并保证了结果可重现
plt.scatter(data[:,0],data[:,1],c=target)

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier()
tree.fit(data,target)
tree.score(data,target)
# Out:
# 1.0

# %%
tree.tree_.max_depth
# Out:
# 4

# %%
#画决策边界
def plot_border(data,target,tree):
    x_test = np.linspace(data[:,0].min(),data[:,0].max(),1000)
    y_test = np.linspace(data[:,1].min(),data[:,1].max(),1000)
    X,Y = np.meshgrid(x_test,y_test)
    XY = np.c_[X.ravel(),Y.ravel()]
    y_=tree.predict(XY)
    plt.pcolormesh(X,Y,y_.reshape(1000,1000))
    plt.scatter(data[:,0],data[:,1],c=target,cmap='rainbow')

# %%
plot_border(data,target,tree)

# %%
#画出不同max_depth下的决策边界
def plot_border_for_max_depth(data,target,TreeClass):
    x_test = np.linspace(data[:,0].min(),data[:,0].max(),1000)
    y_test = np.linspace(data[:,1].min(),data[:,1].max(),1000)
    X,Y = np.meshgrid(x_test,y_test)
    XY = np.c_[X.ravel(),Y.ravel()]

    plt.figure(figsize=(3*5,3*5))
    params = np.arange(1,10)
    for i,params in enumerate(params):
        tree = TreeClass(max_depth=params)
        tree.fit(data,target)
        score = tree.score(data,target)
        axes = plt.subplot(3,3,i+1)
        y_=tree.predict(XY)
        axes.pcolormesh(X,Y,y_.reshape(1000,1000))
        axes.scatter(data[:,0],data[:,1],c=target,cmap='rainbow')
        axes.set_title(f'max_depth={params},score={score}')

# %%
plot_border_for_max_depth(data,target,DecisionTreeClassifier)

# %% [markdown]
# #### 4分类

# %%
data,target = make_blobs(centers=4,random_state=0)
plt.scatter(data[:,0],data[:,1],c=target)

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier()
tree.fit(data,target)
tree.score(data,target)
# Out:
# 1.0

# %%
tree.tree_.max_depth
# Out:
# 7

# %%
plot_border(data, target, tree)

# %%
plot_border_for_max_depth(data, target, DecisionTreeClassifier)

# %% [markdown]
# #### 5分类

# %%
data, target = make_blobs(centers=5, random_state=1)
plt.scatter(data[:,0], data[:,1], c=target)

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier()
tree.fit(data, target)
tree.score(data, target)
# Out:
# 1.0

# %%
tree.tree_.max_depth
# Out:
# 5

# %%
plot_border(data, target, tree)

# %%
plot_border_for_max_depth(data, target, DecisionTreeClassifier)

# %% [markdown]
# ### RandomForestClassifier

# %% [markdown]
# #### 3分类

# %%
from sklearn.datasets import make_blobs
data,target = make_blobs(centers=3,random_state=0)
plt.scatter(data[:,0],data[:,1],c=target)

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(data, target)
rf.score(data, target)
# Out:
# 1.0

# %%
plot_border(data, target, rf)

# %%
plot_border_for_max_depth(data, target, RandomForestClassifier)

# %% [markdown]
# #### 4分类

# %%
data, target = make_blobs(centers=4, random_state=0)
plt.scatter(data[:,0], data[:,1], c=target)

# %%
rf = RandomForestClassifier()
rf.fit(data, target)
rf.score(data, target)
# Out:
# 1.0

# %%
plot_border(data, target, rf)

# %%
plot_border_for_max_depth(data, target, RandomForestClassifier)

# %% [markdown]
# #### 5分类

# %%
#random_state:设置随机数种子，保证结果可复现
data, target = make_blobs(centers=5, random_state=1)
plt.scatter(data[:,0], data[:,1], c=target)

# %%
rf = RandomForestClassifier()
rf.fit(data, target)
rf.score(data, target)
# Out:
# 1.0

# %%
plot_border(data, target, rf)

# %%
plot_border_for_max_depth(data, target, RandomForestClassifier)

# %% [markdown]
# ### 对比决策树和随机森林

# %%
data,target = make_blobs(centers=2,random_state=0)
plt.scatter(data[:,0],data[:,1],c=target)

# %%
#对比不同max_dapth下的决策树和随机森林的边界线
def plot_border_for_trees(TreeClass1,TreeClass2,centers=5,n=6,random_state=0):
    data,target = make_blobs(centers=centers,random_state=random_state)
    x_test = np.linspace(data[:,0].min(),data[:,0].max(),1000)
    y_test = np.linspace(data[:,1].min(),data[:,1].max(),1000)
    X,Y = np.meshgrid(x_test,y_test)
    XY =np.c_[X.ravel(),Y.ravel()]

    plt.figure(figsize=(3*5,3*5))
    params = np.arange(1,n+1)
    for i,param in enumerate(params):
        axes0 = plt.subplot(n,3,3*i+1)
        axes0.scatter(data[:,0],data[:,1],c=target)
        axes0.set_title(f'centers={centers}')

        tree1 = TreeClass1(max_depth=param)
        tree1.fit(data,target)
        score = tree1.score(data,target)
        axes1 = plt.subplot(n,3,3*i+2)
        y1_=tree1.predict(XY)
        axes1.pcolormesh(X,Y,y1_.reshape(1000,1000))
        axes1.scatter(data[:,0],data[:,1],c=target,cmap='rainbow')
        axes1.set_ylabel(f'{TreeClass1.__name__}')
        axes1.set_title(f'max_depth={params},score]{score}')

        tree2 = TreeClass2(max_depth=param)
        tree2.fit(data, target)
        score = tree2.score(data, target)
        axes2 = plt.subplot(n, 3, 3*i+3)
        y2_ = tree2.predict(XY)
        axes2.pcolormesh(X, Y, y2_.reshape(1000,1000))
        axes2.scatter(data[:,0], data[:,1], c=target, cmap='rainbow')
        axes2.set_ylabel(f'{TreeClass2.__name__}')
        axes2.set_title(f'max_depth={param}, score={score}')

# %% [markdown]
# #### 2分类

# %%
plot_border_for_trees(DecisionTreeClassifier, RandomForestClassifier, n=6, centers=2, random_state=0)

# %% [markdown]
# #### 3分类

# %%
plot_border_for_trees(DecisionTreeClassifier,RandomForestClassifier,n=6,centers=3,random_state=0)

# %% [markdown]
# #### 4分类

# %%
plot_border_for_trees(DecisionTreeClassifier,RandomForestClassifier,n=6,centers=4,random_state=0)

# %% [markdown]
# #### 5分类

# %%
plot_border_for_trees(DecisionTreeClassifier,RandomForestClassifier,n=6,centers=5,random_state=0)
